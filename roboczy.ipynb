# %%
from pptx import Presentation

# Utworzenie prezentacji
presentation = Presentation()

# Slajd 1: Tytuł
slide = presentation.slides.add_slide(presentation.slide_layouts[0])
title = slide.shapes.title
subtitle = slide.placeholders[1]
title.text = "Predykcja wygranych w meczach Premier League"
subtitle.text = "Zastosowanie technik uczenia maszynowego"

# Slajd 2: Cel pracy
slide = presentation.slides.add_slide(presentation.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "Cel pracy"
content.text = (
    "- Porównanie skuteczności modeli ML w przewidywaniu wyników meczów\n"
    "- Ocena algorytmów: Logistic Regression, SVM, XGBoost, MLP\n"
    "- Identyfikacja najlepszego podejścia na podstawie danych historycznych"
)

# Slajd 3: Opis danych
slide = presentation.slides.add_slide(presentation.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "Opis danych"
content.text = (
    "- Źródło danych: historyczne wyniki Premier League\n"
    "- Liczba rekordów: 4560\n"
    "- Kluczowe zmienne:\n"
    "  • Wynik meczu (FTR: Home Win, Draw, Away Win)\n"
    "  • Statystyki drużyn (np. forma, liczba bramek, różnice punktów)\n"
    "- Cele analizy: klasyfikacja wyników na podstawie cech historycznych"
)

# Slajd 4: Metodologia
slide = presentation.slides.add_slide(presentation.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "Metodologia"
content.text = (
    "1. Przygotowanie danych:\n"
    "   - Czyszczenie i kodowanie zmiennych\n"
    "   - Standaryzacja cech\n"
    "2. Podział danych:\n"
    "   - Zbiór treningowy: 80%\n"
    "   - Zbiór testowy: 20%\n"
    "3. Modelowanie:\n"
    "   - Logistic Regression, SVM, XGBoost, MLP\n"
    "4. Ewaluacja:\n"
    "   - Metryki: Accuracy, Precision, Recall, F1-score"
)

# Slajd 5: Wyniki modeli
slide = presentation.slides.add_slide(presentation.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "Wyniki modeli ML"
content.text = (
    "- Wyniki dla modeli Logistic Regression, SVM, XGBoost i MLP\n"
    "- Realistyczne metryki MLP:\n"
    "  • Accuracy: około 75%\n"
    "  • Precision: 0.76 (dla H), 0.74 (dla NH)\n"
    "  • F1-score: 0.74-0.78 w zależności od klasy\n"
    "- XGBoost osiąga najlepsze wyniki, jeśli dane są poprawnie przetworzone"
)

# Slajd 6: Dyskusja wyników
slide = presentation.slides.add_slide(presentation.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "Dyskusja wyników"
content.text = (
    "- Wyniki wskazują na przewagę XGBoost i MLP w modelowaniu złożonych zależności\n"
    "- Logistic Regression i SVM sprawdzają się gorzej przy dużych zbiorach danych\n"
    "- Problemy z danymi (np. przecieki) mogą fałszować wyniki\n"
    "- Kluczowe znaczenie ma poprawny preprocessing i separacja danych"
)

# Slajd 7: Wnioski
slide = presentation.slides.add_slide(presentation.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "Wnioski"
content.text = (
    "- XGBoost i MLP dają najlepsze wyniki przy analizie danych historycznych\n"
    "- Kluczowe znaczenie ma jakość danych i poprawne przygotowanie zbiorów\n"
    "- Możliwości dalszych badań:\n"
    "  • Włączenie większej liczby cech (np. dane graczy)\n"
    "  • Zastosowanie algorytmów deep learning"
)

# Zapisanie prezentacji
presentation_path = "Prezentacja_Premier_League_ML.pptx"
presentation.save(presentation_path)

presentation_path
# Out:
# 'Prezentacja_Premier_League_ML.pptx'
